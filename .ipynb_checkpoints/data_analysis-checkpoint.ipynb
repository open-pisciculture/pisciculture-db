# %% [markdown]
# # Data Analysis
#
# Here we need a `.csv` file in order to do the desired analysis.

# %%
import json
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('formatted_data_nov03.csv')
df["datetime"] = pd.to_datetime(df["Datetime"])
# df = df.set_index('datetime')
del df["Datetime"]
df["approx datetime"] = df["datetime"].round('1min') # redondeamos a los X mins más cercanos (X según frec. de los videos)

# del df["Turbidity"]
# del df["pH"]
# del df["Light"]
df = df.sort_values('datetime', ignore_index=True)
# df = df.sort_index()
df.head(10)
# Out:
#    Water Temperature  Ambient Temperature  Humidity  Water Level   Rain  \
# 0              16.13                 13.9      86.0        31.39  805.0
# 1              16.19                 13.9      86.0        31.41  809.0
# 2              16.19                 13.9      86.0        30.98  779.0
# 3              16.13                 13.9      86.0        31.51  807.0
# 4              16.19                 13.9      86.0        31.49  796.0
# 5              16.13                 13.9      86.0        31.41  783.0
# 6              16.13                 13.9      86.0        30.73  811.0
# 7              16.19                 13.9      86.0        31.10  771.0
# 8              16.19                 13.9      86.0        31.03  783.0
# 9              16.13                 13.9      86.0        31.41  833.0
#
#    Light   UV  Turbidity  Dissolved Oxygen    pH  Total Dissolved Solids  \
# 0   13.0  0.0   -1466.85              7.70  1.87                  279.61
# 1   13.0  0.0   -1682.96              7.57  2.10                  277.95
# 2   13.0  0.0   -1452.62              7.61  2.09                  278.78
# 3   13.0  0.0   -1424.23              7.79  2.12                  275.48
# 4   13.0  0.0   -1610.36              7.66  2.09                  277.13
# 5   12.0  0.0   -1410.07              7.66  1.98                  277.95
# 6   13.0  0.0   -1481.10              7.74  1.88                  280.44
# 7   13.0  0.0   -1452.62              7.66  1.99                  277.13
# 8   13.0  0.0   -1481.10              7.74  1.94                  275.48
# 9   13.0  0.0   -1438.41              7.74  2.09                  277.95
#
#              datetime     approx datetime
# 0 2021-11-03 01:28:01 2021-11-03 01:28:00
# 1 2021-11-03 01:28:06 2021-11-03 01:28:00
# 2 2021-11-03 01:28:11 2021-11-03 01:28:00
# 3 2021-11-03 01:28:16 2021-11-03 01:28:00
# 4 2021-11-03 01:28:21 2021-11-03 01:28:00
# 5 2021-11-03 01:28:26 2021-11-03 01:28:00
# 6 2021-11-03 01:28:31 2021-11-03 01:29:00
# 7 2021-11-03 01:28:36 2021-11-03 01:29:00
# 8 2021-11-03 01:28:41 2021-11-03 01:29:00
# 9 2021-11-03 01:28:46 2021-11-03 01:29:00

# %%
start_time = df.head(1)['datetime']
end_time = df.tail(1)['datetime']

print(f"Data starts at: {start_time}")
print(f"Data ends at: {end_time}")
# Out:
# Data starts at: 0   2021-11-03 01:28:01
# Name: datetime, dtype: datetime64[ns]
# Data ends at: 18146   2021-11-04 01:27:56
# Name: datetime, dtype: datetime64[ns]

# %%
#understanding correlation
plt.figure(figsize = (15,9))
sns.heatmap(df.corr(), annot = True)

# %% [markdown]
# ## Strongly Correlated Variables

# %%
sns.scatterplot(x=df["Dissolved Oxygen"], y=df["Ambient Temperature"], data=df)

# %%
sns.scatterplot(x=df["Humidity"], y=df["Ambient Temperature"], data=df)

# %%
sns.scatterplot(x=df["Humidity"], y=df["Dissolved Oxygen"], data=df)

# %%
scatter = sns.scatterplot(x=df["Water Temperature"], y=df["Total Dissolved Solids"], data=df)
scatter.set_ylim(top=400);

# %% [markdown]
# ## Weakly/Not at all Corelated Variables

# %%
scatter = sns.scatterplot(x=df["Water Level"], y=df["Rain"], data=df)
scatter.set_xlim(left=25, right=40)
# Out:
# (25, 40)

# %% [markdown]
# # Merging Video Data with Physicochemical Vars

# %%
video_df = pd.read_csv('video_data_Nov3.csv')
video_df["datetime"] = pd.to_datetime(video_df["timestamp"])
del video_df["timestamp"]
video_df["approx datetime"] = video_df["datetime"].round('1min') # redondeamos a los X mins más cercanos (X según frec. de los videos)
# video_df = video_df.set_index('datetime')

video_df = video_df.sort_values('datetime', ignore_index=True)
# video_df = video_df.sort_index()

# %%
video_df.head()
# Out:
#    Average Distance  Average X  Average Y  Average Pairwise Distance  \
# 0        17449.6815        211        118                   121.0598
# 1        15651.2526        284        134                   120.5914
# 2        11962.1188        248        105                   122.6562
# 3        18065.0385        243        136                   149.5691
# 4        35288.4105        236        193                   167.9318
#
#              datetime     approx datetime
# 0 2021-11-03 13:42:29 2021-11-03 13:42:00
# 1 2021-11-03 13:43:29 2021-11-03 13:43:00
# 2 2021-11-03 13:44:29 2021-11-03 13:44:00
# 3 2021-11-03 13:45:29 2021-11-03 13:45:00
# 4 2021-11-03 13:46:30 2021-11-03 13:46:00

# %%
df.head()
# Out:
#    Water Temperature  Ambient Temperature  Humidity  Water Level   Rain  \
# 0              16.13                 13.9      86.0        31.39  805.0
# 1              16.19                 13.9      86.0        31.41  809.0
# 2              16.19                 13.9      86.0        30.98  779.0
# 3              16.13                 13.9      86.0        31.51  807.0
# 4              16.19                 13.9      86.0        31.49  796.0
#
#    Light   UV  Turbidity  Dissolved Oxygen    pH  Total Dissolved Solids  \
# 0   13.0  0.0   -1466.85              7.70  1.87                  279.61
# 1   13.0  0.0   -1682.96              7.57  2.10                  277.95
# 2   13.0  0.0   -1452.62              7.61  2.09                  278.78
# 3   13.0  0.0   -1424.23              7.79  2.12                  275.48
# 4   13.0  0.0   -1610.36              7.66  2.09                  277.13
#
#              datetime     approx datetime
# 0 2021-11-03 01:28:01 2021-11-03 01:30:00
# 1 2021-11-03 01:28:06 2021-11-03 01:30:00
# 2 2021-11-03 01:28:11 2021-11-03 01:30:00
# 3 2021-11-03 01:28:16 2021-11-03 01:30:00
# 4 2021-11-03 01:28:21 2021-11-03 01:30:00

# %%
merged_df = pd.merge(df, video_df, how='inner', left_index=True, right_index=True)
merged_df
# Out:
#                      Water Temperature  Ambient Temperature  Humidity  \
# datetime
# 2021-10-01 08:49:40              13.50                 18.1      65.0
# 2021-10-01 08:49:40              15.06                 18.8      79.0
# 2021-10-01 08:49:40              14.44                 18.9      66.0
# 2021-10-01 08:49:40              11.94                 15.9      74.0
